# %% [markdown]
# # Training logs

# %% [markdown]
# ### First try
# hidden dim = 64
# bidirectional = False
# dropout = 0.0
# no strategies for class imbalance
# lr = 0.01
# epoch = 1
#
# >RESULTS: high accuracy rate before training; improved loss but accuracy rate stay unchanged
#
# ![image.png](attachment:image.png)
#
#
# >COMMENTS: ASVspoof uses EER instead of accuracy to test performance, which is a more suitable evaluation for imbalanced dataset
#
# >NEXT STEPS:
# > 1. use EER for evaluation
# > 2. use weighted cross entropy
# > 3. data scaling
# > 4. testing out different hyperparameters

# %% [markdown]
# ### Second Try
#
# - hyperparamters stay the same as the first try
# - used EER instead of accuracy -> much more reasonable results
#
# trial 1
# ![image.png](attachment:image.png)
#
# trial 2 (with GPU)
# ![image-2.png](attachment:image-2.png)
#
# trial 3 (with GPU)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Thrid Try
#
# - dim 64 -> 128
#
# trial 1
# ![image.png](attachment:image.png)
#
# trial 2 (w/ 10 epochs)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Fourth Try
#
# - bidirectional -> True
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Fifth Try
#
# - n_layer -> 2
#
# ![image.png](attachment:image.png)
#
# >NOTE: not much difference

# %% [markdown]
# ### Sixth Try
#
# - n_layer -> 4
#
# ![image.png](attachment:image.png)
#
# >NOTE: worse performance. possibily vanishing gradient/not proper initialization/no regulation/overfitting/complex landscape

# %% [markdown]
# ### Seventh Try
#
# - Dropout rate: 0.0 -> 0.5
#
# ![image.png](attachment:image.png)
#
# >NOTE: very bad results with big fluctuations

# %% [markdown]
# ### Eighth Try
#
# - Dropout rate: 0.5 -> 0.25
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Nineth Try
#
# - Dropout rate: 0.25 -> 0.1
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Tenth Try
#
# - used weighted entropy
# - dim: 128, n_layer = 1, bidirectional = True, dropout = 0.0
#
#
# Trial 1
#
# ![image.png](attachment:image.png)
#
# >NOTE: similar EER as the non-weighted one (fifth?) but much lower loss -> maybe try more epoches?
#
#
# Trial 2 (20 epoches)
#
# ![image-2.png](attachment:image-2.png)
#
# >NOTE: best result so far, how about decrease the dimensionality & increase # layers?
#
#
# Trial 3
#
# - dim: 128 -> 64
# - n_layer: 1 -> 2
#
# ![image-3.png](attachment:image-3.png)
#
# >NOTE: nah we need to go back to higher dimensions and lower # layers

# %% [markdown]
# # Pitch & HNR

# %% [markdown]
# ### First Try
# Basid setting (dim=128)
#
# ![image.png](attachment:image.png)
#
# >note:no big improvements seen

# %% [markdown]
# ### Second Try
#
# - scaled
# - Basic setting (dim-128)
#
# ![image.png](attachment:image.png)
#
# >note:even worse... probably HNR should play a bigger role in this?

# %% [markdown]
# # Notes on EER

# %% [markdown]
# ## Notes on model improvement
